# %% [markdown]
# <a href="https://colab.research.google.com/github/warisaaom/KKU_Data_Mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab  import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# os for ทำงานเกี่ยวกับไฟล์
import os
# pd เพื่อเรียกใช้ตาราง ในไฟล์
import pandas as pd
# สร้างตัวแปลในชื่อ base_path path คือที่ที่เก็บข้อมูลของเราเอง
base_path = '/content/drive/My Drive/DWDM_material'
# เรียกใช้ไฟล์ในโฟเดอร์
data = pd.read_csv(os.path.join(base_path,'test.csv'))
# show เเค่หัวตาราง
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# plot กราฟแบบ boxplot โดยใช้ค่า X

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# plot กราฟที่ค่า whis=1.2 และตัวตัวแปรเก็บชื่อว่า output¶

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f0e41c96940>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0e41c2f390>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0e41c2fe10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0e41c2fa90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f0e41c96c50>,
#   <matplotlib.lines.Line2D at 0x7f0e41c96fd0>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f0e4176cf28>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0e41779978>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0e41783438>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0e417830b8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f0e41779278>,
#   <matplotlib.lines.Line2D at 0x7f0e417795f8>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %% [markdown]
# เรียกดูข้อมูลใน fliers

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %% [markdown]
# เรียกดูข้อมูลใน whiskers(ค่าoutliner) ทางซ้าย

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %% [markdown]
# เรียกดูข้อมูลใน whiskers(ค่าoutliner) ทางขวา

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# ###scapter plot

# %% [markdown]
# plotกราฟscatter โดยขนาดของจุดเพิ่มขึ้นตามค่า y

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=1)

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='c')

# %% [markdown]
# plotกราฟscatter โดยขนาดของจุดเพิ่มขึ้นตามค่า y และจุดเป็นสีเหลือง

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='y',marker='P')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='*',alpha=0.4)

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='*',alpha=0.4)
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6)

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='*',alpha=0.4)
plt.scatter([44,42,50,35,33,90,93,96,96,96],[15,14,80,80,83,40,43,46,40,33],s=250,alpha=0.6)

# %%
plt.plot(data['x'],data['y'])

# %%
plt.plot(data['x'],data['y'],'ro-')

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200,c='k')

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=range(10,len(data['x'])+10))

# %%
plt.scatter(data['x'],data['y'],s=150,c=[[0.2,0.5,0.3]])

# %%
plt.scatter(data['x'],data['y'],s=150,c=[[0.2,0.5,0.8,0.5]])

# %%
color_list = []
for i in range(len(data['x'])):
  color_list.append([0.2,0.1,i/255,0.5])
color_list
# Out:
# [[0.2, 0.1, 0.0, 0.5],
#  [0.2, 0.1, 0.00392156862745098, 0.5],
#  [0.2, 0.1, 0.00784313725490196, 0.5],
#  [0.2, 0.1, 0.011764705882352941, 0.5],
#  [0.2, 0.1, 0.01568627450980392, 0.5],
#  [0.2, 0.1, 0.0196078431372549, 0.5],
#  [0.2, 0.1, 0.023529411764705882, 0.5],
#  [0.2, 0.1, 0.027450980392156862, 0.5],
#  [0.2, 0.1, 0.03137254901960784, 0.5],
#  [0.2, 0.1, 0.03529411764705882, 0.5],
#  [0.2, 0.1, 0.0392156862745098, 0.5],
#  [0.2, 0.1, 0.043137254901960784, 0.5],
#  [0.2, 0.1, 0.047058823529411764, 0.5],
#  [0.2, 0.1, 0.050980392156862744, 0.5],
#  [0.2, 0.1, 0.054901960784313725, 0.5],
#  [0.2, 0.1, 0.058823529411764705, 0.5],
#  [0.2, 0.1, 0.06274509803921569, 0.5],
#  [0.2, 0.1, 0.06666666666666667, 0.5],
#  [0.2, 0.1, 0.07058823529411765, 0.5],
#  [0.2, 0.1, 0.07450980392156863, 0.5],
#  [0.2, 0.1, 0.0784313725490196, 0.5],
#  [0.2, 0.1, 0.08235294117647059, 0.5],
#  [0.2, 0.1, 0.08627450980392157, 0.5],
#  [0.2, 0.1, 0.09019607843137255, 0.5],
# ...

# %%
plt.scatter(data['x'],data['y'],s=150,c=color_list)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels);

# %%
x = [12,25,7,7,1,1,1,1,5,5,5,5]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a s d f a s d f s a d f e w r w e f s d f'.split())
# Out:
# (array([5., 4., 0., 4., 0., 5., 2., 0., 2., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)
